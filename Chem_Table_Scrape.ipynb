# %% [markdown]
# ## Christian Hansen
# ## Scraping data from an unstructured XML dataset

# %%
import pandas as pd
import re
from bs4 import BeautifulSoup
wiki = "./Wikipedia-20161003174511.xml"
bs = BeautifulSoup(open(wiki,'r').read(),"xml")

# %% [markdown]
# I started by looking into the xml file and breaking up the table or chemboxes. This became easier to do using beautiful soup as well as simple string regex and splitting based on reoccuring patterns. I struggled with various patterns to split on, but it didn't take long to get a feel for how the tables are structured.
#
# The original prompt indicated that it should follow "chemical formula, property, value, units" and while this is sensible, eventually it seemed clearer to me to structure data as various columns correlating to one chemical. Many tables from the xml file had non-matching columns so that was something I tackled when I concatinated the rows together using as a dataframe object. The main downside and something that is easily fixed when the a chemical property is pulled from the data set is separating the value and the units. The column name is the feature name, or property, and the value of the chemical could be the molar mass, if that value existed in the row it would still contain both the value and the unit, seperating by space and slicing from the created array would give both the value and unit of that property.
#
# I made an attempt to separate the unit and value with a function. Regardless, this is not an easy scrape and I'd say that this approach could be implemented better from the get go, but it's a tradeoff of hyper-specifying how to process the data or to be a little greedy and get the number and units together.
# As for the bonus, I ended up encapsulating the data structure for each property according to each chemical. I may have not kept it true to the intended use of the data structure, but I did what I thought was reasonable given how my data was structured. This way, given a single compound you can have all its properties in that exact data type.

# %%
## Trying agian, getting all found section splits
sectioned = bs.findAll(text=re.compile("Chembox\n"))

# %%
# Specific functions to scrape sections 2 and 4, both the properties and thermochemistry tables for a single chemical
def section_2(section):
    array_ret= []
    for s,v in enumerate(section):
        if 'Formula' in v:
            v = (v + re.sub('[=|1 ]','',section[0][s+1]))
        if v.count('=') ==1:
            row = re.sub('[\n|}}]','',v).split('=')
            array_ret.append(row)
    return(array_ret)

def section_four(section):
    array_four = []
    for v in section:
        if ' = ' in v:
            array_four.append(re.sub('[|}\n]','',v).split(' = '))
    return array_four

# %%
## this splits all different chemboxes into unique parts

def get_sections(sectioned,chem_numb):
    if 'Name = ' in sectioned[chem_numb]:
        sections_name = sectioned[chem_numb].split('Name = ')[-1].split('Section')
#         print('name')
        return(sections_name)
    if 'OtherNames = ': 
#         print('othername')
        sections_name = sectioned[chem_numb].split('OtherNames = ')[-1].split('Section')
        return(sections_name)
    
# Separating the sectioned tables and scrapping the name only
    
def section_name(section_name):
    name_array = sections_name[0].split('\n')[0]
    if len(name_array)>1:
        name = name_array.split('<ref>')[0]
    else:
        name = name_array
    return name


## Extracting both section two and four
def extract_section_two_four(sections_name):
    ## functional section scraping
    name = section_name(sections_name)
    name = ['name',name]
    ## separetely get name of the forumula
    print(name[1])
    section_two_array = []
    section_four_array =[]
    for section in sections_name:
        ## take care of each section individually
        if 'Chembox Properties' in section:
#             print('Properties')
            section_two_array = section_2(section.split('\n| '))
        elif 'Chembox Thermochemistry' in section:
#             print('Thermo')
            
            section_four_array = section_four(section.split('\n| '))

    return(name,section_two_array,section_four_array)

## get the sections and put it into a dataframe row
def get_data_frame(sections_name):
    name, prop,thermo = extract_section_two_four(sections_name)
    column_name = [x[0] for x in (prop[1:]+thermo)] 
    values = [x[1] for x in (prop[1:]+thermo)]
    data_frame = pd.DataFrame(values,index = column_name).T
    data_frame.index = [name[1]]
    return(data_frame)

# %%
#concatinate individual tables into one giant dataframe.
data_frame = pd.DataFrame()
for chem_numb in range(len(sectioned)):
    print(chem_numb)
    try:
        # since some tables aren't transforming well at all and raising a specific error, I'll attempt use try/except
        sections_name = get_sections(sectioned,chem_numb)
        data_frame = pd.concat([data_frame,get_data_frame(sections_name)],axis = 0)
    except:
        pass

## Write dataframe to csv and fix the issues with spaces in the column names.

data_frame.columns = [x.strip(' ') for x in data_frame.columns]
data_frame.to_csv('Chembox_Table.csv',encoding='utf-8')
# Out:
# 0
# Ball and stick model of dimeric aluminium bromide
# 1
# Ball and stick model of aluminium iodide dimer
# 2
# Aluminium Nitride powder
# 3
# Aluminium(3+) trioxidanide
# 4
# Aluminium nitrate
# 5
# Ammonia
# 6
# Ammonium azide
# 7
# Ammonium chromate(IV)
# 8
# {{Unreferenced|date=December 2009}}
# 9
# Ammonium hydroxide
# 10
# Ammonium perchlorate
# 11
#
# 12
# <!-- Barium dioxoironbis(olate) (substitutive) OR Barium tetraoxidoferrate(2-) (additive) -->
# 13
# Beryllium borohydride
# 14
# Beryllium+hydroxide
# 15
# Beryllium nitrate
# 16
#
# 17
# beryllium+oxide
# 18
# Beryllium sulfite
# 19
#
# 20
# borane ''(substitutive)''<br />
# 21
# Boric acid<br />Trihydrooxidoboron<!-- This second IUPAC name has not been validated -->
# 22
# Elbor
# 23
# Boron trifluoride
# 24
# cadmium+selenide
# 25
# Cadmium telluride
# 26
# Caesium bicarbonate
# 27
# Caesium hydride
# 28
# Calcium cyanamide
# 29
# Calcium perchlorate
# 30
# Carbon+dioxide
# 31
# Carbon+monoxide
# 32
# Tetraiodomethane
# 33
# Chlorine+dioxide
# 34
# Chlorosyl
# 35
# chlorine+trifluoride
# 36
# Dihydroxidodioxidochromium
# 37
# Chromium trioxide
# 38
# Chromium(2+) sulfate
# 39
# Dichlorodioxochromium
# 40
# Difluoro(dioxo)chromium
# 41
# Cobalt(III) fluoride
# 42
# Fluorocopper
# 43
# Copper(II) sulfate
# 44
# Cyanogen+Bromide
# 45
# cyanogen+chloride
# 46
# Iodoformonitrile{{Citation needed|date=June 2012}}
# 47
# cyanogen
# 48
# Diborane(6)
# 49
# dichlorine trioxide
# 50
# dichlorosilane
# 51
# Disilane
# 52
# Sulfur+monochloride
# 53
# gallium+arsenide
# 54
# Gallium nitride
# 55
#
# 56
# Ball and stick, cell model of gallium(II) sulfide
# 57
# Digermane
# 58
# Gold(III) trichloride
# 59
# tetra-μ-chlorotetrachlorotetragold
# 60
# Gold(III) fluoride
# 61
# Gold(III) bromide
# 62
# Dihydrogen hexafluorosilicate
# 63
# Hydrazine
# 64
# Hydrogen azide
# 65
# Hydrobromic+Acid
# 66
# Hydrochloric+acid
# 67
# Hydrogen+Cyanide
# 68
# Hydrogen+sulfide
# 69
# Hydroxylamine
# 70
# hypobromous acid, bromic(I) acid
# 71
# Phosphinic acid
# 72
#
# 73
# Iodic acid
# 74
# Pentafluoro-λ<sup>5</sup>-iodane
# 75
#
# 76
# Krypton(II) fluoride
# 77
# Lanthanum carbonate
# 78
# Lead(II) iodide
# 79
# Lead(II) phosphate
# 80
#
# 81
# Lead zirconium titanate
# 82
# Lithium alumanuide
# 83
# Lithium+chloride
# 84
#
# 85
#
# 86
# Lithium hydrosulfide
# 87
# Lithium sulfite
# 88
# Magnesium oxide
# 89
# Manganese(II) chloride<br/>Manganese dichloride
# 90
# Manganese (II) Phosphate
# 91
# dodecachlorohexamolybdenum(II)
# 92
# Hexacarbonylmolybdenum
# 93
# Nickel(II) fluoride
# 94
# Niobium oxytrichloride
# 95
# Nitric+acid
# 96
# Nitric+acid
# 97
# Nitrogen dioxide
# 98
# Dinitrogen monoxide
# 99
# Osmium+tetroxide
# 100
# Ozone
# 101
# {{Chembox
# 102
#
# 103
# Oxo(phenyl)arsine
# 104
# phosphonic acid
# 105
# phosphorus pentabromide
# 106
# Plutonium(III) chloride
# 107
# potassium tetrafluoridoaluminate
# 108
# Potassium carbonate
# 109
# Potassium manganate(VII)
# 110
# Potassium sulphate
# 111
# <!-- Iron(3+) hexacyanoirontetrauide (substitutive) OR Iron(3+) hexacyanidoferrate(4-) (additive)-->
# 112
# Radon difluoride
# 113
# Rubidium nitrate
# 114
#
# 115
# Silane
# 116
# {{Chembox
# 117
# Metasilicic acid
# 118
# Silicon+carbide
# 119
# Silicon+dioxide
# 120
# Silicon+monoxide
# 121
# Silicon+nitride
# 122
# <!-- Tetrabromosilane (substitutive) OR Tetrabromidosilicon (additive) -->
# 123
# Silver(I) phosphate
# 124
#
# 125
# Sodium+bicarbonate
# 126
# Sodium+borohydride
# 127
# Sodium+chlorate
# 128
# Sodium+chloride
# 129
# Sodium+Hydroxide
# 130
#
# 131
# Sodium selenate
# 132
# sodium selenide
# 133
# Sodium+metasilicate
# 134
# Sodium thiosulfate
# 135
# sodium tetrahydroxidozincate(2−)
# 136
# Strontium+titanium+oxide
# 137
# Sulfur+dioxide
# 138
# Sulfur+hexafluoride
# 139
# Disulfur+decafluoride
# 140
# Stereo, skeletal formula of tetrasulfur tetranitride with some measurements
# 141
# Thallium monofluoride{{Citation needed|date = October 2011}}<br />
# 142
# trimethyl+phosphine
# 143
# Trioxidane
# 144
# Ball and stick model of crystalline uranyl hydroxide
# 145
# trichlorooxo+vanadium
# 146

# %%
data_frame.head()
# Out:
#                                                   Appearance Absorbance  \
# Ball and stick model of dimeric aluminium bromide        NaN        NaN
# Ball and stick model of aluminium iodide dimer           NaN        NaN
# Aluminium Nitride powder                                 NaN
# Aluminium(3+) trioxidanide                               NaN        NaN
# Aluminium nitrate                                        NaN        NaN
#
#                                                                                           Appearance  \
# Ball and stick model of dimeric aluminium bromide       white to pale yellow<br /> crystalline solid
# Ball and stick model of aluminium iodide dimer      white powder<br />but impure samples<br />are...
# Aluminium Nitride powder                                                  white to pale-yellow solid
# Aluminium(3+) trioxidanide                                                White [[amorphous]] powder
# Aluminium nitrate                                       White crystals, solid <br /> [[hygroscopic]]
#
#                                                   AtmosphericOHRateConstant  \
# Ball and stick model of dimeric aluminium bromide                       NaN
# Ball and stick model of aluminium iodide dimer                          NaN
# Aluminium Nitride powder                                                NaN
# Aluminium(3+) trioxidanide                                              NaN
# Aluminium nitrate                                                       NaN
#
#                                                   BandGap BoilingPt  \
# Ball and stick model of dimeric aluminium bromide     NaN       NaN
# Ball and stick model of aluminium iodide dimer        NaN       NaN
# Aluminium Nitride powder                              NaN       NaN
# Aluminium(3+) trioxidanide                            NaN
# Aluminium nitrate                                     NaN       NaN
#
#                                                   BoilingPtC BoilingPtK  \
# Ball and stick model of dimeric aluminium bromide       265         NaN
# Ball and stick model of aluminium iodide dimer           360        NaN
# Aluminium Nitride powder                                2517        NaN
# Aluminium(3+) trioxidanide                               NaN        NaN
# Aluminium nitrate                                        150        NaN
#
#                                                              BoilingPt_notes  \
# Ball and stick model of dimeric aluminium bromide                        NaN
# Ball and stick model of aluminium iodide dimer                    , sublimes
# Aluminium Nitride powder                                          decomposes
# Aluminium(3+) trioxidanide                                               NaN
# Aluminium nitrate                                   (nonahydrate) decomposes
#
#                                                   BoilingPt_ref  \
# Ball and stick model of dimeric aluminium bromide           NaN
# Ball and stick model of aluminium iodide dimer              NaN
# Aluminium Nitride powder                                    NaN
# Aluminium(3+) trioxidanide                                  NaN
# Aluminium nitrate                                           NaN
#
#                                                                                                                                                                                                                            ...                                                                                                                                                                           \
# Ball and stick model of dimeric aluminium bromide                                                                                                                                                                          ...
# Ball and stick model of aluminium iodide dimer                                                                                                                                                                             ...
# Aluminium Nitride powder                                                                                                                                                                                                   ...
# Aluminium(3+) trioxidanide                                                                                                                                                                                                 ...
# Aluminium nitrate                                                                                                                                                                                                          ...
#
#                                                   Solvent4 Solvent5  \
# Ball and stick model of dimeric aluminium bromide      NaN      NaN
# Ball and stick model of aluminium iodide dimer         NaN      NaN
# Aluminium Nitride powder                               NaN      NaN
# Aluminium(3+) trioxidanide                             NaN      NaN
# Aluminium nitrate                                      NaN      NaN
#
#                                                   SpecRotation  \
# Ball and stick model of dimeric aluminium bromide          NaN
# Ball and stick model of aluminium iodide dimer             NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                                 NaN
# Aluminium nitrate                                          NaN
#
#                                                   SublimationConditions  \
# Ball and stick model of dimeric aluminium bromide                   NaN
# Ball and stick model of aluminium iodide dimer                      NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                                          NaN
# Aluminium nitrate                                                   NaN
#
#                                                   ThermalConductivity  \
# Ball and stick model of dimeric aluminium bromide                 NaN
# Ball and stick model of aluminium iodide dimer                    NaN
# Aluminium Nitride powder                                  285 W/(m·K)
# Aluminium(3+) trioxidanide                                        NaN
# Aluminium nitrate                                                 NaN
#
#                                                   VaporPressure Viscosity  \
# Ball and stick model of dimeric aluminium bromide           NaN       NaN
# Ball and stick model of aluminium iodide dimer              NaN       NaN
# Aluminium Nitride powder                                    NaN
# Aluminium(3+) trioxidanide                                  NaN       NaN
# Aluminium nitrate                                           NaN
#
#                                                      pKa  pKb  \
# Ball and stick model of dimeric aluminium bromide    NaN  NaN
# Ball and stick model of aluminium iodide dimer       NaN  NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                          >7    NaN
# Aluminium nitrate
#
#                                                   tetragonal<br/>tP36, P4<sub>1</sub>2<sub>1</sub>2, No. 92<ref>{{cite journal doi=10.1524/zkri.1959.112.1-6.409 title=The crystal structure of keatite, a new form of silica year=1959 last1=Shropshire first1=Joseph last2=Keat first2=Paul P. last3=Vaughan first3=Philip A. journal=Zeitschrift für Kristallographie volume=112 pages=409–13bibcode
# Ball and stick model of dimeric aluminium bromide                                                NaN
# Ball and stick model of aluminium iodide dimer                                                   NaN
# Aluminium Nitride powder                                                                         NaN
# Aluminium(3+) trioxidanide                                                                       NaN
# Aluminium nitrate                                                                                NaN
#
# [5 rows x 62 columns]

# %%
#checking to see if it can be read in alright. Looking good
read_in_df = pd.read_csv('Chembox_Table.csv')
read_in_df.index = read_in_df['Unnamed: 0']
read_in_df.index.rename('Name',inplace = True)
read_in_df.drop('Unnamed: 0',inplace = True,axis =1)
read_in_df.drop('Appearance',inplace = True,axis =1)
read_in_df.head()
# Out:
#                                                   Absorbance  \
# Name
# Ball and stick model of dimeric aluminium bromide        NaN
# Ball and stick model of aluminium iodide dimer           NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                               NaN
# Aluminium nitrate                                        NaN
#
#                                                                                         Appearance.1  \
# Name
# Ball and stick model of dimeric aluminium bromide       white to pale yellow<br /> crystalline solid
# Ball and stick model of aluminium iodide dimer      white powder<br />but impure samples<br />are...
# Aluminium Nitride powder                                                  white to pale-yellow solid
# Aluminium(3+) trioxidanide                                                White [[amorphous]] powder
# Aluminium nitrate                                       White crystals, solid <br /> [[hygroscopic]]
#
#                                                   AtmosphericOHRateConstant  \
# Name
# Ball and stick model of dimeric aluminium bromide                       NaN
# Ball and stick model of aluminium iodide dimer                          NaN
# Aluminium Nitride powder                                                NaN
# Aluminium(3+) trioxidanide                                              NaN
# Aluminium nitrate                                                       NaN
#
#                                                   BandGap BoilingPt  \
# Name
# Ball and stick model of dimeric aluminium bromide     NaN       NaN
# Ball and stick model of aluminium iodide dimer        NaN       NaN
# Aluminium Nitride powder                              NaN       NaN
# Aluminium(3+) trioxidanide                            NaN       NaN
# Aluminium nitrate                                     NaN       NaN
#
#                                                   BoilingPtC BoilingPtK  \
# Name
# Ball and stick model of dimeric aluminium bromide       265         NaN
# Ball and stick model of aluminium iodide dimer           360        NaN
# Aluminium Nitride powder                                2517        NaN
# Aluminium(3+) trioxidanide                               NaN        NaN
# Aluminium nitrate                                        150        NaN
#
#                                                              BoilingPt_notes  \
# Name
# Ball and stick model of dimeric aluminium bromide                        NaN
# Ball and stick model of aluminium iodide dimer                    , sublimes
# Aluminium Nitride powder                                          decomposes
# Aluminium(3+) trioxidanide                                               NaN
# Aluminium nitrate                                   (nonahydrate) decomposes
#
#                                                   BoilingPt_ref  \
# Name
# Ball and stick model of dimeric aluminium bromide           NaN
# Ball and stick model of aluminium iodide dimer              NaN
# Aluminium Nitride powder                                    NaN
# Aluminium(3+) trioxidanide                                  NaN
# Aluminium nitrate                                           NaN
#
#                                                   Closely related to α-quartz (with an Si-O-Si angle of 155°) and optically active; β-quartz converts to β-tridymite at 1140 K[[File:b-quartz.png100px]]-[[tridymiteα-tridymite]][[orthorhombic]]<br/>oS24, C222<sub>1</sub>, No.20<ref name=trid>{{cite journal doi=10.1524/zkri.1986.177.1-2.27 title=Structural change of orthorhombic-Itridymite with temperature: A study based on second-order thermal-vibrational parameters year=1986 last1=Kihara first1=Kuniaki last2=Matsumoto first2=Takeo last3=Imamura first3=Moritaka journal=Zeitschrift für Kristallographie volume=177 pages=27–38bibcode  \
# Name
# Ball and stick model of dimeric aluminium bromide                                                NaN
# Ball and stick model of aluminium iodide dimer                                                   NaN
# Aluminium Nitride powder                                                                         NaN
# Aluminium(3+) trioxidanide                                                                       NaN
# Aluminium nitrate                                                                                NaN
#
#                                                                                                                                                                                                                            ...                                                                                                                                                                           \
# Name                                                                                                                                                                                                                       ...
# Ball and stick model of dimeric aluminium bromide                                                                                                                                                                          ...
# Ball and stick model of aluminium iodide dimer                                                                                                                                                                             ...
# Aluminium Nitride powder                                                                                                                                                                                                   ...
# Aluminium(3+) trioxidanide                                                                                                                                                                                                 ...
# Aluminium nitrate                                                                                                                                                                                                          ...
#
#                                                   Solvent4 Solvent5  \
# Name
# Ball and stick model of dimeric aluminium bromide      NaN      NaN
# Ball and stick model of aluminium iodide dimer         NaN      NaN
# Aluminium Nitride powder                               NaN      NaN
# Aluminium(3+) trioxidanide                             NaN      NaN
# Aluminium nitrate                                      NaN      NaN
#
#                                                   SpecRotation  \
# Name
# Ball and stick model of dimeric aluminium bromide          NaN
# Ball and stick model of aluminium iodide dimer             NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                                 NaN
# Aluminium nitrate                                          NaN
#
#                                                   SublimationConditions  \
# Name
# Ball and stick model of dimeric aluminium bromide                   NaN
# Ball and stick model of aluminium iodide dimer                      NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                                          NaN
# Aluminium nitrate                                                   NaN
#
#                                                   ThermalConductivity  \
# Name
# Ball and stick model of dimeric aluminium bromide                 NaN
# Ball and stick model of aluminium iodide dimer                    NaN
# Aluminium Nitride powder                                  285 W/(m·K)
# Aluminium(3+) trioxidanide                                        NaN
# Aluminium nitrate                                                 NaN
#
#                                                   VaporPressure Viscosity  \
# Name
# Ball and stick model of dimeric aluminium bromide           NaN       NaN
# Ball and stick model of aluminium iodide dimer              NaN       NaN
# Aluminium Nitride powder                                    NaN
# Aluminium(3+) trioxidanide                                  NaN       NaN
# Aluminium nitrate                                           NaN
#
#                                                      pKa  pKb  \
# Name
# Ball and stick model of dimeric aluminium bromide    NaN  NaN
# Ball and stick model of aluminium iodide dimer       NaN  NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                          >7    NaN
# Aluminium nitrate                                    NaN  NaN
#
#                                                   tetragonal<br/>tP36, P4<sub>1</sub>2<sub>1</sub>2, No. 92<ref>{{cite journal doi=10.1524/zkri.1959.112.1-6.409 title=The crystal structure of keatite, a new form of silica year=1959 last1=Shropshire first1=Joseph last2=Keat first2=Paul P. last3=Vaughan first3=Philip A. journal=Zeitschrift für Kristallographie volume=112 pages=409–13bibcode
# Name
# Ball and stick model of dimeric aluminium bromide                                                NaN
# Ball and stick model of aluminium iodide dimer                                                   NaN
# Aluminium Nitride powder                                                                         NaN
# Aluminium(3+) trioxidanide                                                                       NaN
# Aluminium nitrate                                                                                NaN
#
# [5 rows x 61 columns]

# %% [markdown]
# #### Checking to see if my function matches up with what I've created

# %%
section_2(sectioned[23].split('Name = ')[-1].split('Section')[2].split('\n|'))
## comparing my dataframe to my list
# Out:
# [[u'2', u'{{Chembox Properties'],
#  [u' Formula ', u' BF<sub>3</sub>{'],
#  [u' MolarMass ',
#   u' 67.82 g/mol (anhydrous) <br /> 103.837 g/mol (dihydrate)'],
#  [u' Appearance ',
#   u' colorless gas (anhydrous) <br /> colorless liquid (dihydrate)'],
#  [u' Density ',
#   u' 0.00276 g/cm<sup>3</sup> (anhydrous gas) <br /> 1.64 g/cm<sup>3</sup> (dihydrate)'],
#  [u' SolubleOther ',
#   u' soluble in [[benzene]], [[toluene]], [[hexane]], [[chloroform]] and [[methylene chloride]]'],
#  [u' MeltingPtC ', u' \u2212126.8'],
#  [u' BoilingPtC ', u' \u2212100.3'],
#  [u' Dipole ', u' 0 D']]

# %%
sections_name = get_sections(sectioned,23)
get_data_frame(sections_name)
# Out:
# Boron trifluoride
#                            Formula   \
# Boron trifluoride   BF<sub>3</sub>{
#
#                                                           MolarMass   \
# Boron trifluoride   67.82 g/mol (anhydrous) <br /> 103.837 g/mol ...
#
#                                                          Appearance   \
# Boron trifluoride   colorless gas (anhydrous) <br /> colorless li...
#
#                                                             Density   \
# Boron trifluoride   0.00276 g/cm<sup>3</sup> (anhydrous gas) <br ...
#
#                                                        SolubleOther   \
# Boron trifluoride   soluble in [[benzene]], [[toluene]], [[hexane...
#
#                   MeltingPtC  BoilingPtC  Dipole        DeltaHf       DeltaGf  \
# Boron trifluoride      −126.8      −100.3     0 D  -1137 kJ/mol  -1120 kJ/mol
#
#                          Entropy     HeatCapacity
# Boron trifluoride  254.3 J/mol K  50.46 J/mol K

# %% [markdown]
# This is a quality/sanity check of the scrape and the reformating of the data.

# %%
data_frame.head(5)
# Out:
#                                                   Appearance Absorbance  \
# Ball and stick model of dimeric aluminium bromide        NaN        NaN
# Ball and stick model of aluminium iodide dimer           NaN        NaN
# Aluminium Nitride powder                                 NaN
# Aluminium(3+) trioxidanide                               NaN        NaN
# Aluminium nitrate                                        NaN        NaN
#
#                                                                                           Appearance  \
# Ball and stick model of dimeric aluminium bromide       white to pale yellow<br /> crystalline solid
# Ball and stick model of aluminium iodide dimer      white powder<br />but impure samples<br />are...
# Aluminium Nitride powder                                                  white to pale-yellow solid
# Aluminium(3+) trioxidanide                                                White [[amorphous]] powder
# Aluminium nitrate                                       White crystals, solid <br /> [[hygroscopic]]
#
#                                                   AtmosphericOHRateConstant  \
# Ball and stick model of dimeric aluminium bromide                       NaN
# Ball and stick model of aluminium iodide dimer                          NaN
# Aluminium Nitride powder                                                NaN
# Aluminium(3+) trioxidanide                                              NaN
# Aluminium nitrate                                                       NaN
#
#                                                   BandGap BoilingPt  \
# Ball and stick model of dimeric aluminium bromide     NaN       NaN
# Ball and stick model of aluminium iodide dimer        NaN       NaN
# Aluminium Nitride powder                              NaN       NaN
# Aluminium(3+) trioxidanide                            NaN
# Aluminium nitrate                                     NaN       NaN
#
#                                                   BoilingPtC BoilingPtK  \
# Ball and stick model of dimeric aluminium bromide       265         NaN
# Ball and stick model of aluminium iodide dimer           360        NaN
# Aluminium Nitride powder                                2517        NaN
# Aluminium(3+) trioxidanide                               NaN        NaN
# Aluminium nitrate                                        150        NaN
#
#                                                              BoilingPt_notes  \
# Ball and stick model of dimeric aluminium bromide                        NaN
# Ball and stick model of aluminium iodide dimer                    , sublimes
# Aluminium Nitride powder                                          decomposes
# Aluminium(3+) trioxidanide                                               NaN
# Aluminium nitrate                                   (nonahydrate) decomposes
#
#                                                   BoilingPt_ref  \
# Ball and stick model of dimeric aluminium bromide           NaN
# Ball and stick model of aluminium iodide dimer              NaN
# Aluminium Nitride powder                                    NaN
# Aluminium(3+) trioxidanide                                  NaN
# Aluminium nitrate                                           NaN
#
#                                                                                                                                                                                                                            ...                                                                                                                                                                           \
# Ball and stick model of dimeric aluminium bromide                                                                                                                                                                          ...
# Ball and stick model of aluminium iodide dimer                                                                                                                                                                             ...
# Aluminium Nitride powder                                                                                                                                                                                                   ...
# Aluminium(3+) trioxidanide                                                                                                                                                                                                 ...
# Aluminium nitrate                                                                                                                                                                                                          ...
#
#                                                   Solvent4 Solvent5  \
# Ball and stick model of dimeric aluminium bromide      NaN      NaN
# Ball and stick model of aluminium iodide dimer         NaN      NaN
# Aluminium Nitride powder                               NaN      NaN
# Aluminium(3+) trioxidanide                             NaN      NaN
# Aluminium nitrate                                      NaN      NaN
#
#                                                   SpecRotation  \
# Ball and stick model of dimeric aluminium bromide          NaN
# Ball and stick model of aluminium iodide dimer             NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                                 NaN
# Aluminium nitrate                                          NaN
#
#                                                   SublimationConditions  \
# Ball and stick model of dimeric aluminium bromide                   NaN
# Ball and stick model of aluminium iodide dimer                      NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                                          NaN
# Aluminium nitrate                                                   NaN
#
#                                                   ThermalConductivity  \
# Ball and stick model of dimeric aluminium bromide                 NaN
# Ball and stick model of aluminium iodide dimer                    NaN
# Aluminium Nitride powder                                  285 W/(m·K)
# Aluminium(3+) trioxidanide                                        NaN
# Aluminium nitrate                                                 NaN
#
#                                                   VaporPressure Viscosity  \
# Ball and stick model of dimeric aluminium bromide           NaN       NaN
# Ball and stick model of aluminium iodide dimer              NaN       NaN
# Aluminium Nitride powder                                    NaN
# Aluminium(3+) trioxidanide                                  NaN       NaN
# Aluminium nitrate                                           NaN
#
#                                                      pKa  pKb  \
# Ball and stick model of dimeric aluminium bromide    NaN  NaN
# Ball and stick model of aluminium iodide dimer       NaN  NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                          >7    NaN
# Aluminium nitrate
#
#                                                   tetragonal<br/>tP36, P4<sub>1</sub>2<sub>1</sub>2, No. 92<ref>{{cite journal doi=10.1524/zkri.1959.112.1-6.409 title=The crystal structure of keatite, a new form of silica year=1959 last1=Shropshire first1=Joseph last2=Keat first2=Paul P. last3=Vaughan first3=Philip A. journal=Zeitschrift für Kristallographie volume=112 pages=409–13bibcode
# Ball and stick model of dimeric aluminium bromide                                                NaN
# Ball and stick model of aluminium iodide dimer                                                   NaN
# Aluminium Nitride powder                                                                         NaN
# Aluminium(3+) trioxidanide                                                                       NaN
# Aluminium nitrate                                                                                NaN
#
# [5 rows x 62 columns]

# %%
read_in_df.head(5)
# Out:
#                                                   Absorbance  \
# Name
# Ball and stick model of dimeric aluminium bromide        NaN
# Ball and stick model of aluminium iodide dimer           NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                               NaN
# Aluminium nitrate                                        NaN
#
#                                                                                         Appearance.1  \
# Name
# Ball and stick model of dimeric aluminium bromide       white to pale yellow<br /> crystalline solid
# Ball and stick model of aluminium iodide dimer      white powder<br />but impure samples<br />are...
# Aluminium Nitride powder                                                  white to pale-yellow solid
# Aluminium(3+) trioxidanide                                                White [[amorphous]] powder
# Aluminium nitrate                                       White crystals, solid <br /> [[hygroscopic]]
#
#                                                   AtmosphericOHRateConstant  \
# Name
# Ball and stick model of dimeric aluminium bromide                       NaN
# Ball and stick model of aluminium iodide dimer                          NaN
# Aluminium Nitride powder                                                NaN
# Aluminium(3+) trioxidanide                                              NaN
# Aluminium nitrate                                                       NaN
#
#                                                   BandGap BoilingPt  \
# Name
# Ball and stick model of dimeric aluminium bromide     NaN       NaN
# Ball and stick model of aluminium iodide dimer        NaN       NaN
# Aluminium Nitride powder                              NaN       NaN
# Aluminium(3+) trioxidanide                            NaN       NaN
# Aluminium nitrate                                     NaN       NaN
#
#                                                   BoilingPtC BoilingPtK  \
# Name
# Ball and stick model of dimeric aluminium bromide       265         NaN
# Ball and stick model of aluminium iodide dimer           360        NaN
# Aluminium Nitride powder                                2517        NaN
# Aluminium(3+) trioxidanide                               NaN        NaN
# Aluminium nitrate                                        150        NaN
#
#                                                              BoilingPt_notes  \
# Name
# Ball and stick model of dimeric aluminium bromide                        NaN
# Ball and stick model of aluminium iodide dimer                    , sublimes
# Aluminium Nitride powder                                          decomposes
# Aluminium(3+) trioxidanide                                               NaN
# Aluminium nitrate                                   (nonahydrate) decomposes
#
#                                                   BoilingPt_ref  \
# Name
# Ball and stick model of dimeric aluminium bromide           NaN
# Ball and stick model of aluminium iodide dimer              NaN
# Aluminium Nitride powder                                    NaN
# Aluminium(3+) trioxidanide                                  NaN
# Aluminium nitrate                                           NaN
#
#                                                   Closely related to α-quartz (with an Si-O-Si angle of 155°) and optically active; β-quartz converts to β-tridymite at 1140 K[[File:b-quartz.png100px]]-[[tridymiteα-tridymite]][[orthorhombic]]<br/>oS24, C222<sub>1</sub>, No.20<ref name=trid>{{cite journal doi=10.1524/zkri.1986.177.1-2.27 title=Structural change of orthorhombic-Itridymite with temperature: A study based on second-order thermal-vibrational parameters year=1986 last1=Kihara first1=Kuniaki last2=Matsumoto first2=Takeo last3=Imamura first3=Moritaka journal=Zeitschrift für Kristallographie volume=177 pages=27–38bibcode  \
# Name
# Ball and stick model of dimeric aluminium bromide                                                NaN
# Ball and stick model of aluminium iodide dimer                                                   NaN
# Aluminium Nitride powder                                                                         NaN
# Aluminium(3+) trioxidanide                                                                       NaN
# Aluminium nitrate                                                                                NaN
#
#                                                                                                                                                                                                                            ...                                                                                                                                                                           \
# Name                                                                                                                                                                                                                       ...
# Ball and stick model of dimeric aluminium bromide                                                                                                                                                                          ...
# Ball and stick model of aluminium iodide dimer                                                                                                                                                                             ...
# Aluminium Nitride powder                                                                                                                                                                                                   ...
# Aluminium(3+) trioxidanide                                                                                                                                                                                                 ...
# Aluminium nitrate                                                                                                                                                                                                          ...
#
#                                                   Solvent4 Solvent5  \
# Name
# Ball and stick model of dimeric aluminium bromide      NaN      NaN
# Ball and stick model of aluminium iodide dimer         NaN      NaN
# Aluminium Nitride powder                               NaN      NaN
# Aluminium(3+) trioxidanide                             NaN      NaN
# Aluminium nitrate                                      NaN      NaN
#
#                                                   SpecRotation  \
# Name
# Ball and stick model of dimeric aluminium bromide          NaN
# Ball and stick model of aluminium iodide dimer             NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                                 NaN
# Aluminium nitrate                                          NaN
#
#                                                   SublimationConditions  \
# Name
# Ball and stick model of dimeric aluminium bromide                   NaN
# Ball and stick model of aluminium iodide dimer                      NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                                          NaN
# Aluminium nitrate                                                   NaN
#
#                                                   ThermalConductivity  \
# Name
# Ball and stick model of dimeric aluminium bromide                 NaN
# Ball and stick model of aluminium iodide dimer                    NaN
# Aluminium Nitride powder                                  285 W/(m·K)
# Aluminium(3+) trioxidanide                                        NaN
# Aluminium nitrate                                                 NaN
#
#                                                   VaporPressure Viscosity  \
# Name
# Ball and stick model of dimeric aluminium bromide           NaN       NaN
# Ball and stick model of aluminium iodide dimer              NaN       NaN
# Aluminium Nitride powder                                    NaN
# Aluminium(3+) trioxidanide                                  NaN       NaN
# Aluminium nitrate                                           NaN
#
#                                                      pKa  pKb  \
# Name
# Ball and stick model of dimeric aluminium bromide    NaN  NaN
# Ball and stick model of aluminium iodide dimer       NaN  NaN
# Aluminium Nitride powder
# Aluminium(3+) trioxidanide                          >7    NaN
# Aluminium nitrate                                    NaN  NaN
#
#                                                   tetragonal<br/>tP36, P4<sub>1</sub>2<sub>1</sub>2, No. 92<ref>{{cite journal doi=10.1524/zkri.1959.112.1-6.409 title=The crystal structure of keatite, a new form of silica year=1959 last1=Shropshire first1=Joseph last2=Keat first2=Paul P. last3=Vaughan first3=Philip A. journal=Zeitschrift für Kristallographie volume=112 pages=409–13bibcode
# Name
# Ball and stick model of dimeric aluminium bromide                                                NaN
# Ball and stick model of aluminium iodide dimer                                                   NaN
# Aluminium Nitride powder                                                                         NaN
# Aluminium(3+) trioxidanide                                                                       NaN
# Aluminium nitrate                                                                                NaN
#
# [5 rows x 61 columns]

# %% [markdown]
# While there are a lot of NaN there are a fair number of actual columns that are populated. Some columns are more populated than others. It's hard to know what will be grabbed so this is a pretty greedy scrape. And eventually it would be best to clean up the columns and specify object types to perform modeling or recall from the dataframe effectively.

# %% [markdown]
# ## Based on which column you'd like to recall you can split the value and units

# %%
# columns =data_frame.columns[data_frame.columns!='Appearance']
columns = [ u'Entropy',u'ThermalConductivity', u'VaporPressure', u'Viscosity',
        u'pKa', u'pKb','DeltaGf', u'DeltaHc', u'DeltaHf', u'Density', u'Dipole',u'HenryConstant', u'IsoelectricPt', u'LambdaMax', u'LogP', u'MagSus',
       u'MeltingPt', u'MeltingPt', u'MeltingPtC', u'MeltingPtF', u'MeltingPtK',
       u'MeltingPt_notes', u'MeltingPt_ref', u'MolarMass', u'O', u'Odor',
       u'Odour', u'Properties_ref', u'RefractIndex', u'RefractIndex',
       u'Solubility', u'Solubility1', u'Solubility2', u'Solubility2',
       u'Solubility3', u'SolubilityProduct', u'SolubilityProductAs',
       u'SolubleOther', u'Solvent', u'Solvent1', u'Solvent2', u'Solvent3',
       u'Solvent4', u'Solvent5', u'SpecRotation', u'SublimationConditions',
       u'ThermalConductivity', u'VaporPressure', u'Viscosity', u'pKa', u'pKb',]

#getting column names

# %%
## helper function to split the value of each row
def split_val(x):
    if len(x)>1:
        return((x[0],x[1:]))
    else:
        return(x)

# %%
# splitting data to get value and units separetely

def split_units(col,data_frame):
    return(data_frame[data_frame[col].notnull()][col].str.strip(' ').str.split(' ').apply(lambda x: split_val(x)))

# %%
col = 'BandGap'
split_units(col,read_in_df)
# Out:
# Name
# beryllium+oxide                         (10.6, [eV])
# cadmium+selenide                        (1.74, [eV])
# Cadmium telluride    (1.5, [eV, (@300, K,, direct)])
# gallium+arsenide         (1.424, [eV, (at, 300, K)])
# Gallium nitride       (3.4, [eV, (300, K,, direct)])
# NaN                                     (0.17, [eV])
# Lead(II) iodide                          (2.3, [eV])
# Name: BandGap, dtype: object

# %%
## looping through all the columns
for col in columns:
    print('Column: ' + col)
    print(split_units(col,read_in_df))
    print('-------------------------------------------------------------------')
# Out:
# Column: Entropy
# Name
# Aluminium Nitride powder                                          (20.2, [J/mol, K])
# Ammonia                            (193&nbsp;J·mol<sup>−1</sup>·K<sup>−1</sup><re...
# Ammonium chromate(IV)                                               (657, [J/K·mol])
# Ammonium hydroxide                 (111&nbsp;J·mol<sup>−1</sup>·K<sup>−1</sup><re...
# Beryllium+hydroxide                (47, [J·mol<sup>−1</sup>·K<sup>−1</sup><ref>{{...
# beryllium+oxide                    (13.73–13.81, [J K<sup>−1</sup> mol<sup>−1</su...
# borane ''(substitutive)''<br />     (187.88, [kJ, mol<sup>−1</sup>, K<sup>−1</sup>])
# Elbor                                                            (14.77, [J/K, mol])
# Boron trifluoride                                                (254.3, [J/mol, K])
# Carbon+dioxide                          [214&nbsp;J·mol<sup>−1</sup>·K<sup>−1</sup>]
# Carbon+monoxide                         (197.7, [J·mol<sup>−1</sup>·K<sup>−1</sup>])
# Chlorine+dioxide                     (257.22, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# chlorine+trifluoride               (281.59, [J, K<sup>−1</sup>mol<sup>−1</sup><re...
# Chromium trioxide                  (73.2, [J/mol·K<ref, name=chemister>[http://ch...
# Copper(II) sulfate                          (5, [J K<sup>−1</sup> mol<sup>−1</sup>])
# cyanogen+chloride                    (236.33, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# cyanogen                             (241.57, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# dichlorosilane                       (286.72, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# Hydrazine                            (121.52, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# Hydrobromic+Acid                   (198.696-198.704, [J, K<sup>−1</sup>, mol<sup>...
# Hydrochloric+acid                   (186.902, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# Hydrogen+Cyanide                     (113.01, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# Hydrogen+sulfide                   (206&nbsp;J, [mol<sup>−1</sup>, K<sup>−1</sup>...
# Hydroxylamine                        (236.18, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# NaN                                (149&nbsp;J·mol<sup>−1</sup>·K<sup>−1</sup><re...
# Lithium alumanuide                                                (87.9, [J/mol, K])
# Lithium+chloride                          (59.31, [J/mol·K<ref, name=chemister, />])
# NaN                                                                (105, [J/mol, K])
# Lithium hydrosulfide                                                (63, [J/mol, K])
# Magnesium oxide                    (26.9&nbsp;J·mol<sup>−1</sup>·K<sup>−1</sup><r...
# Nitric+acid                        (146&nbsp;J·mol<sup>−1</sup>·K<sup>−1</sup><re...
# Nitrogen dioxide                   (240&nbsp;J&nbsp;mol<sup>−1</sup>&nbsp;K<sup>−...
# Dinitrogen monoxide                (219.96, [J&thinsp;K<sup>−1</sup>&thinsp;mol<s...
# Ozone                                (238.92, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# Potassium manganate(VII)           (171.7, [J&thinsp;K<sup>−1</sup>&thinsp;mol<su...
# Silane                             (204.6, [J&thinsp;mol<sup>−1</sup>&thinsp;K<su...
# Silicon+dioxide                    (42&nbsp;J·mol<sup>−1</sup>·K<sup>−1</sup><ref...
# NaN                                                               (70.4, [J/mol, K])
# Sodium+bicarbonate                                                 (102, [J/mol, K])
# Sodium+chlorate                           (129.7, [J/mol·K<ref, name=chemister, />])
# Sodium+chloride                       (72.11, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# Sodium+Hydroxide                   (64&nbsp;J·mol<sup>−1</sup>·K<sup>−1</sup><ref...
# sodium selenide                                                    (105, [J/mol, K])
# Sodium+metasilicate                  (113.71, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# Sulfur+dioxide                      (248.223, [J, K<sup>−1</sup>, mol<sup>−1</sup>])
# Sulfur+hexafluoride                (292&nbsp;J·mol<sup>−1</sup>·K<sup>−1</sup><re...
# Name: Entropy, dtype: object
# -------------------------------------------------------------------
# Column: ThermalConductivity
# Name
# Aluminium Nitride powder                                     (285, [W/(m·K)])
# beryllium+oxide                    (330, [W, K<sup>−1</sup>, m<sup>−1</sup>])
# gallium+arsenide                             (0.55, [W/(cm·K), (at, 300, K)])
# Gallium nitride             (1.3, [W/(cm·K), (300, K), <ref>Mion,, Christi...
# NaN                         (180, [mW, K<sup>−1</sup>, cm<sup>−1</sup>, (a...
# Magnesium oxide             (45–60&nbsp;W·m<sup>−1</sup>·K<sup>−1</sup><re...
# Name: ThermalConductivity, dtype: object
# -------------------------------------------------------------------
# Column: VaporPressure
# Name
# Ammonia                                       (8573, [h, Pa])
# NaN                                                        []
# Beryllium nitrate                                          []
# Carbon+dioxide                        (5.73, [MPa, (20, °C)])
# chlorine+trifluoride                             (175, [kPa])
# Cyanogen+Bromide                                (16.2, [kPa])
# cyanogen+chloride          (1.987, [MPa, (at, 21.1&nbsp;°C)])
# dichlorosilane                   (167.2, [kPa, (at, 20, °C)])
# Hydrazine                       (1, [kP, (at, 30.7&nbsp;°C)])
# Hydrobromic+Acid             (2.308, [MPa, (at, 21&nbsp;°C)])
# Hydrogen+sulfide              (1740, [kPa, (at, 21&nbsp;°C)])
# Lead(II) phosphate                                         []
# Nitrogen dioxide             (98.80, [kPa, (at, 20&nbsp;°C)])
# Dinitrogen monoxide                   (5150, [kPa, (20, °C)])
# Sodium+Hydroxide              (<2.4, [kPa, (at, 20&nbsp;°C)])
# Sulfur+dioxide                                 (237.2, [kPa])
# Sulfur+hexafluoride      (2.9&nbsp;MPa, [(at, 21.1&nbsp;°C)])
# trimethyl+phosphine           (49.9, [kPa, (at, 20&nbsp;°C)])
# trichlorooxo+vanadium             (1.84, [kPa, (at, 20, °C)])
# Name: VaporPressure, dtype: object
# -------------------------------------------------------------------
# Column: Viscosity
# Name
# Aluminium Nitride powder                                                  []
# Aluminium nitrate                                                         []
# Ammonia                                       (0.276, [cP, (&minus;40, °C)])
# Ammonium perchlorate                                                      []
# Carbon+dioxide                      (0.07, [[[PoisecP]], at, −78.5&nbsp;°C])
# chlorine+trifluoride                                       (91.82, [μPa, s])
# Hydrazine                                                      (0.876, [cP])
# Hydrogen azide                                                            []
# Hydrochloric+acid                                  (0.311, [cP, (−100, °C)])
# Hydrogen+Cyanide                                             (201, [μPa, s])
# Phosphinic acid                                                           []
# Pentafluoro-λ<sup>5</sup>-iodane                                          []
# Sulfur+dioxide                                (0.403, [cP, (at, 0&nbsp;°C)])
# Name: Viscosity, dtype: object
# -------------------------------------------------------------------
# Column: pKa
# Name
# Aluminium Nitride powder                                                                                                                   []
# Aluminium(3+) trioxidanide                                                                                                               [>7]
# Ammonia                                                                                     (32.5, [(−33&nbsp;°C),<ref>Perrin,, D., D.,, '...
# NaN                                                                                                                                        []
# Beryllium nitrate                                                                                                                          []
# Boric acid<br />Trihydrooxidoboron<!-- This second IUPAC name has not been validated -->                               (9.24,, [12.4,, 13.3])
# Carbon+dioxide                                                                                                               (6.35,, [10.33])
# Chlorine+dioxide                                                                                                                     [3.0(5)]
# Dihydroxidodioxidochromium                                                                                                  (-0.8, [to, 1.6])
# Gold(III) bromide                                                                                                                          []
# Hydrogen azide                                                                              (4.6, [<ref>Pradyot, Patnaik., ''Handbook, of,...
# Hydrobromic+Acid                                                                            (-8.8, [(±0.8);<ref>Trummal,, A.;, Lipping,, L...
# Hydroxylamine                                                                                                                          [5.95]
# hypobromous acid, bromic(I) acid                                                                                                       [8.65]
# Phosphinic acid                                                                                                                         [1.2]
# Iodic acid                                                                                                                             [0.75]
# Pentafluoro-λ<sup>5</sup>-iodane                                                                                                           []
# NaN                                                                                                                                        []
# Lanthanum carbonate                                                                                                                        []
# Lead(II) phosphate                                                                                                                         []
# Manganese(II) chloride<br/>Manganese dichloride                                                                                            []
# Nitric+acid                                                                                                                           [3.398]
# phosphonic acid                                                                                                                 (1.3,, [6.7])
# Metasilicic acid                                                                                                              (9.84,, [13.2])
# NaN                                                                                                                                        []
# Sulfur+dioxide                                                                                                                         [1.81]
# Name: pKa, dtype: object
# -------------------------------------------------------------------
# Column: pKb
# Name
# Aluminium Nitride powder                                                                          []
# Ammonia                                                                                       [4.75]
# NaN                                                                                               []
# Beryllium nitrate                                                                                 []
# Gold(III) bromide                                                                                 []
# Hydrazine                                                                                     [5.90]
# Hydrobromic+Acid                                                                               [~23]
# Hydrochloric+acid                                                                             [17.0]
# Hydrogen+Cyanide                                                                              [4.79]
# Hydrogen+sulfide                                                                              [12.9]
# Hydroxylamine                                                                                 [8.05]
# Pentafluoro-λ<sup>5</sup>-iodane                                                                  []
# NaN                                                                                               []
# Lanthanum carbonate                                                                               []
# Lead(II) phosphate                                                                                []
# Lithium sulfite                                                                                   []
# Manganese(II) chloride<br/>Manganese dichloride                                                   []
# Sodium+Hydroxide                                   (0.2<ref>[http://chemwiki.ucdavis.edu/Physical...
# NaN                                                                                               []
# Sodium thiosulfate                                                                                []
# Sulfur+dioxide                                                                               [12.19]
# Name: pKb, dtype: object
# -------------------------------------------------------------------
# Column: DeltaGf
# Name
# Aluminium Nitride powder                           (287.4, [kJ/mol])
# Beryllium+hydroxide                                 (-818, [kJ/mol])
# beryllium+oxide                                     (-582, [kJ/mol])
# Elbor                                             (-226.8, [kJ/mol])
# Boron trifluoride                                  (-1120, [kJ/mol])
# Lithium alumanuide                                 (-48.4, [kJ/mol])
# Lithium+chloride            (-384, [kJ/mol<ref, name=chemister, />])
# NaN                                               (-389.5, [kJ/mol])
# Magnesium oxide                                   (-596.6, [kJ/mol])
# Potassium manganate(VII)                          (-713.8, [kJ/mol])
# Sodium+bicarbonate                                (-851.9, [kJ/mol])
# Sodium+chlorate             (-275, [kJ/mol<ref, name=chemister, />])
# Sodium+Hydroxide                                  (-380.7, [kJ/mol])
# Sodium+metasilicate                                (-1427, [kJ/mol])
# Name: DeltaGf, dtype: object
# -------------------------------------------------------------------
# Column: DeltaHc
# Name
# Carbon+monoxide                                  (−283.4, [kJ/mol])
# Tetraiodomethane            (−794.4–−778.4, [kJ, mol<sup>−1</sup>])
# cyanogen                  (−1.0978–−1.0942, [MJ, mol<sup>−1</sup>])
# Hydrogen+Cyanide                   (-426.5, [kJ, mol<sup>−1</sup>])
# NaN                                                (25.5, [kH/mol])
# Hexacarbonylmolybdenum            (−2123.4, [kJ, mol<sup>−1</sup>])
# Name: DeltaHc, dtype: object
# -------------------------------------------------------------------
# Column: DeltaHf
# Name
# Aluminium Nitride powder                                                                (318, [kJ/mol])
# Aluminium(3+) trioxidanide                            (−1277&nbsp;kJ·mol<sup>−1</sup><ref>{{cite, [b...
# Ammonia                                               (−46&nbsp;kJ·mol<sup>−1</sup><ref, [name=b1>{{...
# Ammonium chromate(IV)                                                                 (-1163, [kJ/mol])
# Ammonium hydroxide                                    (−80&nbsp;kJ·mol<sup>−1</sup><ref, [name=b1>{{...
# Beryllium borohydride                                                                  (-108, [kJ/mol])
# Beryllium+hydroxide                                   (-904, [kJ, mol<sup>−1</sup><ref>{{cite, book,...
# Beryllium nitrate                                                                    (-700.4, [kJ/mol])
# beryllium+oxide                                       (–599, [kJ mol<sup>−1</sup><ref>{{cite, book, ...
# borane ''(substitutive)''<br />                                        (106.69, [kJ, mol<sup>−1</sup>])
# Elbor                                                                               (-250.91, [kJ/mol])
# Boron trifluoride                                                                     (-1137, [kJ/mol])
# Carbon+dioxide                                                        [−393.5&nbsp;kJ·mol<sup>−1</sup>]
# Carbon+monoxide                                                         (−110.5, [kJ·mol<sup>−1</sup>])
# Tetraiodomethane                                                  (384.0–400.4, [kJ, mol<sup>−1</sup>])
# Chlorine+dioxide                                                                     (104.60, [kJ/mol])
# Chlorosyl                                               (101.8, [kJ/mol<ref, name="holleman_wiberg"/>])
# chlorine+trifluoride                                        (−158.87, [kJ, mol<sup>−1</sup><ref, name])
# Chromium trioxide                                     (−589.3, [kJ/mol<ref, name=pphoic>{{cite, book...
# Copper(II) sulfate                                                                  (−769.98, [kJ/mol])
# Cyanogen+Bromide                                                  (136.1–144.7, [kJ, mol<sup>−1</sup>])
# cyanogen+chloride                                                      (137.95, [kJ, mol<sup>−1</sup>])
# Iodoformonitrile{{Citation needed|date=June 2012}}                (160.5–169.1, [kJ, mol<sup>−1</sup>])
# cyanogen                                                               (309.07, [kJ, mol<sup>−1</sup>])
# dichlorosilane                                                        (−320.49, [kJ, mol<sup>−1</sup>])
# Gold(III) fluoride                                                                   (-363.3, [kJ/mol])
# Hydrazine                                                               (50.63, [kJ, mol<sup>−1</sup>])
# Hydrobromic+Acid                                      (−36.45, [–, −36.13, kJ, mol<sup>−1</sup><ref,...
# Hydrogen+Cyanide                                                        (109.9, [kJ, mol<sup>−1</sup>])
# Hydrogen+sulfide                                      (−21&nbsp;kJ, [mol<sup>−1</sup><ref, name=b1>{...
# Hydroxylamine                                                           (−39.9, [kJ, mol<sup>−1</sup>])
# NaN                                                   (−920&nbsp;kJ·mol<sup>−1</sup><ref, [name=b1>{...
# Lithium alumanuide                                                                     (-117, [kJ/mol])
# Lithium+chloride                                            (-408.27, [kJ/mol<ref, name=chemister, />])
# NaN                                                                (-7.007, [kJ/g, or, -482.3, kJ/mol])
# Lithium hydrosulfide                                                 (-9.401, [kJ/g, or, -447, kJ/mol])
# Magnesium oxide                                       (−601.8&nbsp;kJ·mol<sup>−1</sup><ref, [name=b1...
# Hexacarbonylmolybdenum                                                 (−989.1, [kJ, mol<sup>−1</sup>])
# Nitric+acid                                           (−207&nbsp;kJ·mol<sup>−1</sup><ref, [name=b1>{...
# Nitrogen dioxide                                      (+34&nbsp;kJ&nbsp;mol<sup>−1</sup><ref, [name=...
# Dinitrogen monoxide                                              (+82.05, [kJ&thinsp;mol<sup>−1</sup>])
# Ozone                                                                  (142.67, [kJ, mol<sup>−1</sup>])
# Potassium manganate(VII)                                                             (−813.4, [kJ/mol])
# Silane                                                                                    [34.31kJ/mol]
# Silicon+dioxide                                       (−911&nbsp;kJ·mol<sup>−1</sup><ref, [name=b1>{...
# NaN                                                                                 (-1133.2, [kJ/mol])
# Sodium+bicarbonate                                                                   (-947.7, [kJ/mol])
# Sodium+chlorate                                              (-365.4, [kJ/mol<ref, name=chemister, />])
# Sodium+chloride                                                       (−411.12, [kJ, mol<sup>−1</sup>])
# Sodium+Hydroxide                                      (−427&nbsp;kJ·mol<sup>−1</sup><ref, [name=b1>{...
# sodium selenide                                                                        (-343, [kJ/mol])
# Sodium+metasilicate                                                  (−1561.43, [kJ, mol<sup>−1</sup>])
# Sulfur+dioxide                                                        (−296.81, [kJ, mol<sup>−1</sup>])
# Sulfur+hexafluoride                                   (−1209&nbsp;kJ·mol<sup>−1</sup><ref, [name=b1>...
# Name: DeltaHf, dtype: object
# -------------------------------------------------------------------
# Column: Density
# Name
# Ball and stick model of dimeric aluminium bromide                                                                 (3.205, [g/cm<sup>3</sup>])
# Ball and stick model of aluminium iodide dimer                                              (3.98, [g/cm<sup>3</sup>, (anhydrous), <br>, 2...
# Aluminium Nitride powder                                                                                          (3.260, [g/cm<sup>3</sup>])
# Aluminium(3+) trioxidanide                                                                                 (2.42, [g/cm<sup>3</sup>,, solid])
# Aluminium nitrate                                                                                   (1.72, [g/cm<sup>3</sup>, (nonahydrate)])
# Ammonium azide                                                                                                 [1.3459&nbsp;g/cm<sup>3</sup>]
# Ammonium chromate(IV)                                                                                                          (1.90, [g/ml])
# {{Unreferenced|date=December 2009}}                                                                                (2.42, [g/cm<sup>3</sup>])
# Ammonium hydroxide                                                                          (0.91&nbsp;g/cm<sup>3</sup>, [(25, %, w/w)<br,...
# Ammonium perchlorate                                                                                               (1.95, [g/cm<sup>3</sup>])
# NaN                                                                                                                                        []
# Beryllium borohydride                                                                                             (0.604, [g/cm<sup>3</sup>])
# Beryllium+hydroxide                                                                         (1.92, [g, cm<sup>−3</sup><ref>Pradyot, Patnai...
# Beryllium nitrate                                                                                                  (1.56, [g/cm<sup>3</sup>])
# NaN                                                                                                                (2.71, [g/cm<sup>3</sup>])
# beryllium+oxide                                                                                                  (3.01, [g, cm<sup>−3</sup>])
# Beryllium sulfite                                                                                                                          []
# Boric acid<br />Trihydrooxidoboron<!-- This second IUPAC name has not been validated -->                          (1.435, [g/cm<sup>3</sup>])
# Elbor                                                                                          (2.1, [(hBN);, 3.45, (cBN), g/cm<sup>3</sup>])
# Boron trifluoride                                                                           (0.00276, [g/cm<sup>3</sup>, (anhydrous, gas),...
# cadmium+selenide                                                                                                (5.816, [g, cm<sup>−3</sup>])
# Caesium bicarbonate                                                                                                                        []
# Calcium cyanamide                                                                                                  (2.29, [g/cm<sup>3</sup>])
# Calcium perchlorate                                                                                                          (2.651, [g/cm3])
# Carbon+dioxide                                                                              (1562, [kg/m<sup>3</sup>, <small>(solid, at, 1...
# Carbon+monoxide                                                                             (789&nbsp;kg/m<sup>3</sup>,, [liquid<br, />1.2...
# Tetraiodomethane                                                                                                 (4.32, [g, mL<sup>−1</sup>])
# Chlorosyl                                                                                                                                  []
# chlorine+trifluoride                                                                                               (4, [mg, cm<sup>−3</sup>])
# Dihydroxidodioxidochromium                                                                                      (1.201, [g, cm<sup>−3</sup>])
#                                                                                                                   ...
# Oxo(phenyl)arsine                                                                                                                          []
# phosphonic acid                                                                                         (1.651, [g/cm<sup>3</sup>, (21, °C)])
# phosphorus pentabromide                                                                                            (3.61, [g/cm<sup>3</sup>])
# potassium tetrafluoridoaluminate                                                                                    (2.9, [g/cm<sup>3</sup>])
# Potassium carbonate                                                                                                (2.43, [g/cm<sup>3</sup>])
# Potassium manganate(VII)                                                                                          (2.703, [g/cm<sup>3</sup>])
# Rubidium nitrate                                                                                                   (3.11, [g/cm<sup>3</sup>])
# NaN                                                                                                                                        []
# Silane                                                                                                          (1.342, [g, dm<sup>−3</sup>])
# Silicon+monoxide                                                                                                   (2.13, [g/cm<sup>3</sup>])
# Silicon+nitride                                                                                             (3.2, [g/cm<sup>3</sup>,, solid])
# <!-- Tetrabromosilane (substitutive) OR Tetrabromidosilicon (additive) -->                                        (2.79, [g·cm<sup>−3</sup>])
# Silver(I) phosphate                                                                                               (6.370, [g/cm<sup>3</sup>])
# NaN                                                                                                                 (1.5, [g/cm<sup>3</sup>])
# Sodium+borohydride                                                                                             [1.0740&nbsp;g/cm<sup>3</sup>]
# Sodium+chloride                                                                                                   (2.165, [g/cm<sup>3</sup>])
# Sodium+Hydroxide                                                                                                   (2.13, [g/cm<sup>3</sup>])
# NaN                                                                                         (3.865, [g/cm<sup>3</sup>, (anhydrous), <br>, ...
# Sodium selenate                                                                                                   (3.098, [g/cm<sup>3</sup>])
# Sodium+metasilicate                                                                                              (2.61, [g, cm<sup>−3</sup>])
# Sodium thiosulfate                                                                                                (1.667, [g/cm<sup>3</sup>])
# sodium tetrahydroxidozincate(2−)                                                                                                           []
# Strontium+titanium+oxide                                                                                           (5.11, [g/cm<sup>3</sup>])
# Sulfur+dioxide                                                                                                 (2.6288, [kg, m<sup>−3</sup>])
# Sulfur+hexafluoride                                                                                                           [6.17&nbsp;g/L]
# Disulfur+decafluoride                                                                                              (2.08, [g/cm<sup>3</sup>])
# Thallium monofluoride{{Citation needed|date = October 2011}}<br />                                               (8.36, [g, cm<sup>−3</sup>])
# trimethyl+phosphine                                                                                              (735, [mg, cm<sup>−3</sup>])
# trichlorooxo+vanadium                                                                                           (1.826, [g, mL<sup>−1</sup>])
# NaN                                                                                                                                        []
# Name: Density, dtype: object
# -------------------------------------------------------------------
# Column: Dipole
# Name
# Aluminium Nitride powder                       []
# Boron trifluoride                        (0, [D])
# Carbon+dioxide                           (0, [D])
# Carbon+monoxide             (0.122, [[[DebyeD]]])
# Magnesium oxide                (6.2, [±, 0.6, D])
# Nitric+acid                  (2.17, [±, 0.02, D])
# Name: Dipole, dtype: object
# -------------------------------------------------------------------
# Column: HenryConstant
# Name
# NaN                                                                []
# Beryllium nitrate                                                  []
# Carbon+monoxide                       (1.04, [atm-m<sup>3</sup>/mol])
# Chlorine+dioxide         (4.01, [x, 10<sup>−2</sup>, atm-cu, m/mole])
# cyanogen              (1.9, [μmol, Pa<sup>−1</sup>, kg<sup>−1</sup>])
# Hydrogen+Cyanide       (75, [μmol, Pa<sup>−1</sup>, kg<sup>−1</sup>])
# Lead(II) phosphate                                                 []
# Name: HenryConstant, dtype: object
# -------------------------------------------------------------------
# Column: IsoelectricPt
# Name
# Aluminium Nitride powder    []
# Name: IsoelectricPt, dtype: object
# -------------------------------------------------------------------
# Column: LambdaMax
# Name
# Aluminium Nitride powder    []
# Name: LambdaMax, dtype: object
# -------------------------------------------------------------------
# Column: LogP
# Name
# NaN                          []
# Beryllium nitrate            []
# Hydrazine                [0.67]
# Hydroxylamine          [−0.758]
# Lead(II) phosphate           []
# Nickel(II) fluoride          []
# Dinitrogen monoxide      [0.35]
# Sodium+bicarbonate      [-0.82]
# Name: LogP, dtype: object
# -------------------------------------------------------------------
# Column: MagSus
# Name
# Aluminium Nitride powder    []
# Name: MagSus, dtype: object
# -------------------------------------------------------------------
# Column: MeltingPt
# Name
# potassium tetrafluoridoaluminate    [>]
# Name: MeltingPt, dtype: object
# -------------------------------------------------------------------
# Column: MeltingPt
# Name
# potassium tetrafluoridoaluminate    [>]
# Name: MeltingPt, dtype: object
# -------------------------------------------------------------------
# Column: MeltingPtC
# Name
# Ball and stick model of dimeric aluminium bromide                                                                                      [97.8]
# Ball and stick model of aluminium iodide dimer                                                                                        [189.4]
# Aluminium Nitride powder                                                                                                               [2200]
# Aluminium(3+) trioxidanide                                                                                                              [300]
# Aluminium nitrate                                                                                                                        [66]
# Ammonia                                                                                                                              [−77.73]
# Ammonium azide                                                                                                                          [160]
# Ammonium chromate(IV)                                                                                                                   [185]
# {{Unreferenced|date=December 2009}}                                                                                                     [380]
# Ammonium hydroxide                                                                                                                    [−57.5]
# Beryllium borohydride                                                                                                                  [91.3]
# Beryllium+hydroxide                                                                                                                    [1000]
# Beryllium nitrate                                                                                                                      [60.5]
# NaN                                                                                                                                    [2200]
# beryllium+oxide                                                                                                                        [2507]
# Boric acid<br />Trihydrooxidoboron<!-- This second IUPAC name has not been validated -->                                              [170.9]
# Elbor                                                                                                                                  [2973]
# Boron trifluoride                                                                                                                    [−126.8]
# Cadmium telluride                                                                                                                      [1041]
# Calcium cyanamide                                                                                                                      [1340]
# Calcium perchlorate                                                                                                                     [270]
# Carbon+monoxide                                                                                                                     [−205.02]
# Chlorine+dioxide                                                                                                                        [-59]
# chlorine+trifluoride                                                                                                                 [−76.34]
# Dihydroxidodioxidochromium                                                                                                              [197]
# Chromium trioxide                                                                                                                       [197]
# Difluoro(dioxo)chromium                                                                                                                [31.6]
# Cobalt(III) fluoride                                                                                                                     [92]
# Copper(II) sulfate                                                                                                                      [110]
# Cyanogen+Bromide                                                                                                               (50, [to, 53])
#                                                                                                                   ...
# Dinitrogen monoxide                                                                                                                  [−90.86]
# Osmium+tetroxide                                                                                                                      [40.25]
# NaN                                                                                                                                   [128.5]
# phosphonic acid                                                                                                                        [73.6]
# Plutonium(III) chloride                                                                                                                 [767]
# potassium tetrafluoridoaluminate                                                                                                        [600]
# Potassium carbonate                                                                                                                     [891]
# Potassium manganate(VII)                                                                                                                [240]
# Potassium sulphate                                                                          (1069<ref>Windholtz,, [M, (Ed.), &, Budavari,,...
# Rubidium nitrate                                                                                                                        [310]
# NaN                                                                                                                                   [-99.5]
# Silane                                                                                                                                 [−185]
# Silicon+carbide                                                                                                                        [2730]
# Silicon+monoxide                                                                                                                       [1702]
# <!-- Tetrabromosilane (substitutive) OR Tetrabromidosilicon (additive) -->                                                                [5]
# Silver(I) phosphate                                                                                                                     [849]
# NaN                                                                                                                                    [1650]
# Sodium+bicarbonate                                                                                                                         []
# Sodium+borohydride                                                                                                                      [400]
# Sodium+chlorate                                                                                                                     [248-261]
# Sodium+chloride                                                                                                                         [801]
# Sodium+Hydroxide                                                                                                                        [318]
# sodium selenide                                                                                                                         [875]
# Sodium+metasilicate                                                                                                                    [1088]
# Sodium thiosulfate                                                                                                                     [48.3]
# Strontium+titanium+oxide                                                                                                               [2080]
# Disulfur+decafluoride                                                                                                                   [-53]
# Thallium monofluoride{{Citation needed|date = October 2011}}<br />                                                                      [327]
# trimethyl+phosphine                                                                                                                     [-86]
# trichlorooxo+vanadium                                                                                                                 [-76.5]
# Name: MeltingPtC, dtype: object
# -------------------------------------------------------------------
# Column: MeltingPtF
# Name
# Silicon+nitride    [3,452]
# Name: MeltingPtF, dtype: object
# -------------------------------------------------------------------
# Column: MeltingPtK
# Name
# cadmium+selenide              [1541]
# Carbon+dioxide               [216.6]
# Hydrazine                      [275]
# Hydrogen+Cyanide    (259, [to, 261])
# Ozone                           [81]
# Sulfur+dioxide                 [201]
# Name: MeltingPtK, dtype: object
# -------------------------------------------------------------------
# Column: MeltingPt_notes
# Name
# Ball and stick model of aluminium iodide dimer     ((anhydrous), [<br>, 185&nbsp;°C,, decomposes,...
# Aluminium Nitride powder                                                                          []
# {{Unreferenced|date=December 2009}}                                                   [(decomposes)]
# Ammonium hydroxide                                    ((25%, [w/w)<br, />−91.5&nbsp;°C, (35%, w/w)])
# NaN                                                                                               []
# Beryllium+hydroxide                                                                   [(decomposes)]
# Elbor                                                                          (sublimates, [(cBN)])
# Calcium perchlorate                                                                               []
# Carbon+dioxide                                                 (([[Triple, [point]], at, 5.1, atm)])
# Gold(III) trichloride                                                                 [(decomposes)]
# Gold(III) bromide                                                                                 []
# Lead(II) phosphate                                                                                []
# NaN                                                                                     [decomposes]
# Lithium alumanuide                                                                    [(decomposes)]
# Manganese(II) chloride<br/>Manganese dichloride    ((anhydrous), [<br>, dihydrate, [[Dehydration,...
# Nickel(II) fluoride                                [<ref>http://www.slac.stanford.edu/BFROOT/www/...
# Potassium manganate(VII)                                                              [(decomposes)]
# Rubidium nitrate                                                                        [decomposes]
# Silicon+carbide                                                                       [(decomposes)]
# Silicon+nitride                                                                       [(decomposes)]
# Sodium+bicarbonate                                 ((decomposes, [to, [[sodium, carbonate]], star...
# NaN                                                                                   [(decomposes)]
# Sodium thiosulfate                                                                  [(pentahydrate)]
# Name: MeltingPt_notes, dtype: object
# -------------------------------------------------------------------
# Column: MeltingPt_ref
# Name
# Beryllium nitrate                                                   []
# Calcium cyanamide    (<ref>Pradyot, [Patnaik., ''Handbook, of, Inor...
# NaN                  (<ref>Pradyot, [Patnaik., ''Handbook, of, Inor...
# NaN                  (<ref>CRC, [Handbook, of, Chemistry, and, Phys...
# Name: MeltingPt_ref, dtype: object
# -------------------------------------------------------------------
# Column: MolarMass
# Name
# Ball and stick model of dimeric aluminium bromide                                                              (266.69, [g/mol])
# Ball and stick model of aluminium iodide dimer                                 (407.69495, [g/mol, (anhydrous), <br>, 515.786...
# Aluminium Nitride powder                                                                                      (40.9882, [g/mol])
# Aluminium(3+) trioxidanide                                                                                      (78.00, [g/mol])
# Aluminium nitrate                                                              (212.996, [g/mol, (anhydrous), <br, />, 375.13...
# Ammonia                                                                                                        (17.031, [g/mol])
# Ammonium azide                                                                                               [60.059&nbsp;g/mol]
# Ammonium chromate(IV)                                                                                          (152.07, [g/mol])
# Ammonium hydroxide                                                                                            [35.04&nbsp;g/mol]
# Ammonium perchlorate                                                                                           (117.49, [g/mol])
# NaN                                                                                                            (125.94, [g/mol])
# Beryllium borohydride                                                                                           (38.70, [g/mol])
# Beryllium nitrate                                                                                          (133.021982, [g/mol])
# NaN                                                                                                             (55.06, [g/mol])
# Beryllium sulfite                                                                                              (89.075, [g/mol])
# Boron trifluoride                                                              (67.82, [g/mol, (anhydrous), <br, />, 103.837,...
# Cadmium telluride                                                                                              (240.01, [g/mol])
# Caesium bicarbonate                                                                                           (193.922, [g/mol])
# Caesium hydride                                                                                             (133.91339, [g/mol])
# Calcium cyanamide                                                                                              (80.102, [g/mol])
# Calcium perchlorate                                                                                          (238.9792, [g/mol])
# Carbon+monoxide                                                                                                (28.010, [g/mol])
# Chromium(2+) sulfate                                                                                  (238.13, [(pentahydrate)])
# Dichlorodioxochromium                                                                                        (154.9008, [g/mol])
# Difluoro(dioxo)chromium                                                                                           (112, [g/mol])
# Cobalt(III) fluoride                                                                                          (115.928, [g/mol])
# Cyanogen+Bromide                                                                                (105.921, [g, mol<sup>1−</sup>])
# cyanogen+chloride                                                                                (61.470, [g, mol<sup>−1</sup>])
# Iodoformonitrile{{Citation needed|date=June 2012}}                                             (152.9219, [g, mol<sup>−1</sup>])
# dichlorine trioxide                                                                                           (118.903, [g/mol])
#                                                                                                      ...
# {{Chembox                                                                                                               [128.91]
# NaN                                                                            (227.941, [g/mol, (H<sub>5</sub>IO<sub>6</sub>...
# phosphonic acid                                                                                                 (82.00, [g/mol])
# phosphorus pentabromide                                                                                        (430.49, [g/mol])
# Plutonium(III) chloride                                                                                       (350.322, [g/mol])
# potassium tetrafluoridoaluminate                                                                                           [142]
# Potassium carbonate                                                                                           (138.205, [g/mol])
# Potassium manganate(VII)                                                                                      (158.034, [g/mol])
# Potassium sulphate                                                                                            (174.259, [g/mol])
# Rubidium nitrate                                                                                              (147.473, [g/mol])
# NaN                                                                                                          [148.95&nbsp;g/mol]
# {{Chembox                                                                                                       (60.08, [g/mol])
# Silicon+dioxide                                                                                                 (60.08, [g/mol])
# Silicon+monoxide                                                                                                (44.08, [g/mol])
# NaN                                                                                                             (81.97, [g/mol])
# Sodium+bicarbonate                                                                              (84.0066, [g, mol<sup>−1</sup>])
# Sodium+borohydride                                                                                            [37.83&nbsp;g/mol]
# Sodium+chloride                                                                                   (58.44, [g, mol<sup>−1</sup>])
# Sodium+Hydroxide                                                                                (39.9971, [g, mol<sup>−1</sup>])
# NaN                                                                                                          (213.8918, [g/mol])
# Sodium thiosulfate                                                             (158.11, [g/mol, (anhydrous), <br>, 248.18, g/...
# sodium tetrahydroxidozincate(2−)                                                                              (179.418, [g/mol])
# Strontium+titanium+oxide                                                                                       (183.49, [g/mol])
# Sulfur+dioxide                                                                                   (64.066, [g, mol<sup>−1</sup>])
# Sulfur+hexafluoride                                                                                            (146.06, [g/mol])
# Disulfur+decafluoride                                                                                           (254.1, [g/mol])
# Stereo, skeletal formula of tetrasulfur tetranitride with some measurements                     (184.287, [g, mol<sup>−1</sup>])
# Thallium monofluoride{{Citation needed|date = October 2011}}<br />                                           (223.3817, [g/mol])
# trichlorooxo+vanadium                                                                           (173.300, [g, mol<sup>−1</sup>])
# NaN                                                                                                                    [440.367]
# Name: MolarMass, dtype: object
# -------------------------------------------------------------------
# Column: O
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-995159380a94> in <module>()
#       2 for col in columns:
#       3     print('Column: ' + col)
# ----> 4     print(split_units(col,read_in_df))
#       5     print('-------------------------------------------------------------------')
#
# <ipython-input-78-25628c47d543> in split_units(col, data_frame)
#       2
#       3 def split_units(col,data_frame):
# ----> 4     return(data_frame[data_frame[col].notnull()][col].str.strip(' ').str.split(' ').apply(lambda x: split_val(x)))
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2738         if (name in self._internal_names_set or name in self._metadata or
#    2739                 name in self._accessors):
# -> 2740             return object.__getattribute__(self, name)
#    2741         else:
#    2742             if name in self._info_axis:
#
# //anaconda/lib/python2.7/site-packages/pandas/core/base.pyc in __get__(self, instance, owner)
#     239             # this ensures that Series.str.<method> is well defined
#     240             return self.accessor_cls
# --> 241         return self.construct_accessor(instance)
#     242
#     243     def __set__(self, instance, value):
#
# //anaconda/lib/python2.7/site-packages/pandas/core/strings.pyc in _make_str_accessor(self)
#    1839             # (instead of test for object dtype), but that isn't practical for
#    1840             # performance reasons until we have a str dtype (GH 9343)
# -> 1841             raise AttributeError("Can only use .str accessor with string "
#    1842                                  "values, which use np.object_ dtype in "
#    1843                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %% [markdown]
# It looks like I'm catching a lot, but this is not consistent. There is high variability in how the value/units are organized in the original tables. This would be where I'd like to spend more time looking into how to generalize the splitting or selecting columns that fit a criteria to actually split on.

# %% [markdown]
# ## Looking into the memory footprint of the dataframe

# %%
foot_print = data_frame.memory_usage(deep = True).sum()*1.0/1048576
print('Number of megabytes of the dataframe: %0.04f mb' % foot_print )
# Out:
# Number of megabytes of the dataframe: 0.3866 mb

# %%
foot_print = read_in_df.memory_usage(deep = True).sum()*1.0/1048576
print('Number of megabytes of the dataframe: %0.04f mb' % foot_print )
# Out:
# Number of megabytes of the dataframe: 0.3195 mb

# %% [markdown]
# It's interesting to note how much smaller the footprint of the read in dataframe is compared to the created one.

# %%
data_frame.dtypes.value_counts()
# Out:
# object    62
# dtype: int64

# %%
read_in_df.dtypes.value_counts()
# Out:
# object     59
# float64     2
# dtype: int64

# %% [markdown]
# So there is the difference, I did drop rows and it automatically converted some rows to float64.

# %%
for i,x in enumerate(read_in_df['Formula']):
    x = str(x)
    read_in_df['Formula'][i]=(re.sub('[<sub/>}{} ]','', x))
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# ## Bonus
#
# Use the pypif module to create a PIF from your CSV output.

# %%
# For each row, add its column
from pypif import pif
from pypif.obj import *
def get_dict_pif(df):
   
    # get column names except for formula
    columns = df.columns[df.columns != 'Formula']                 
    chem_array = {}

    ## making an array of each chemicalsystem and an array for properties for each system. 
    ## Essentialy a matrix of dictionaries.

    for index, row in df.iterrows():
        chemical_system = ChemicalSystem()
        chemical_system.chemical_formula = str(row['Formula'])
        properties  = []
        for col in columns:
            value = Property()
            value.property_ = str(col)
            value.value = row[col]
            chemical_system.properties = value
            properties.append(chemical_system.properties)

        chem_array[str(row['Formula'])]= pif.dumps(properties)
    return(chem_array)

# %%
chem_dict_out = get_dict_pif(read_in_df)
chem_dict_out.keys()
# Out:
# ['',
#  'ChemN4S4',
#  'HIO3',
#  'ChemTlFp2\xe2\x80\xa2p',
#  'SF6',
#  'MgO',
#  'GaN',
#  'BeSO3',
#  'LiClO3',
#  'GaA',
#  'ABr3',
#  'AlBr3rAl2Br6',
#  'BF3',
#  'ChemSrTiO3',
#  '(NH4)2CrO4',
#  'Mn3(PO4)2',
#  'RNO2',
#  '(CN)2',
#  'Al(OH)3',
#  'HNO2',
#  'NiF2',
#  'NH4N3,NH3.HN3',
#  'Al(NO3)3',
#  'Ge2H6',
#  'ChemSO2',
#  'AlI3',
#  'LiNO3',
#  'chemPI2',
#  'CrO2Cl2',
#  'ChemSiH2Cl2',
#  'Be(NO3)2',
#  'Si3N4',
#  'chemN2O',
#  'CSO4(anhydro)rCSO4\xc2\xb75H2O(pentahydrate)',
#  'Na2S2O3',
#  'Be3N2',
#  'S2F10',
#  'AF3',
#  'H3PO3',
#  'H3PO2',
#  'SiO2',
#  'Ca(ClO4)2',
#  'P3(PO4)2',
#  'HCN',
#  'La2(CO3)3',
#  'IF5',
#  'Li2S',
#  'CoF3',
#  'CrO2F2',
#  'CrSO4\xc2\xb75H2O',
#  'NH4ClO4',
#  'NH4ClO3',
#  'LiAlH4',
#  'GaSp\xe2\x80\xa2p',
#  'CaCN2',
#  'NaCl',
#  'BrCN',
#  'ChemA4Cl8',
#  'H3AO3',
#  'NH4OH',
#  'FeO',
#  'chemNaHCO3',
#  'H5IO6(orthoperiodic)BRHIO4(metaperiodic)',
#  'ChemUH2O4',
#  'Li2SO3',
#  'KAlF4',
#  'CHCO3',
#  'ACl3r(exitaA2Cl6)',
#  'KMnO4',
#  'CNCl',
#  'Ga2S3',
#  'HN3',
#  'Be(BH4)2',
#  'SeO2F2',
#  'Cl2O3',
#  'Xep+p[PtF6]p\xe2\x88\x92p',
#  'NaClO3',
#  'OO4',
#  'CO',
#  'MnCl2',
#  'PBr5',
#  'Cl12Mo6',
#  'Na2Zn(OH)4',
#  '[[LeadP]][[SlfrS]][[OxygenO]]4',
#  'Na2SiO3',
#  'nan',
#  'NaAlO2',
#  'SiO',
#  'ICN',
#  'NaBH4',
#  'NaIO4',
#  'K2CO3',
#  'NH3',
#  'K2SO4',
#  'BiOCl',
#  'ChemN2H4',
#  "[[LeadP]]nowiki[nowikiZirconim''x''Titanim1-''x''nowiki]nowikiOxygen3(0\xe2\x89\xa4''x''\xe2\x89\xa41)",
#  'ChemNaOH',
#  'S2Cl2',
#  'ChemVOCl3',
#  '[[CaeimC]][[HydrogenH]]',
#  'HBrO']

# %%
# Testing out the returned arrray for AlI3AlS
chem_dict_out['HBrO']
# Out:
# '[{"property": "Absorbance", "value": NaN}, {"property": "Appearance.1", "value": " "}, {"property": "AtmosphericOHRateConstant", "value": NaN}, {"property": "BandGap", "value": NaN}, {"property": "BoilingPt", "value": NaN}, {"property": "BoilingPtC", "value": " 20-25"}, {"property": "BoilingPtK", "value": NaN}, {"property": "BoilingPt_notes", "value": NaN}, {"property": "BoilingPt_ref", "value": NaN}, {"property": "Closely related to \\u03b1-quartz (with an Si-O-Si angle of 155\\u00b0) and optically active; \\u03b2-quartz converts to \\u03b2-tridymite at 1140 K[[File:b-quartz.png100px]]-[[tridymite\\u03b1-tridymite]][[orthorhombic]]<br/>oS24, C222<sub>1</sub>, No.20<ref name=trid>{{cite journal doi=10.1524/zkri.1986.177.1-2.27 title=Structural change of orthorhombic-Itridymite with temperature: A study based on second-order thermal-vibrational parameters year=1986 last1=Kihara first1=Kuniaki last2=Matsumoto first2=Takeo last3=Imamura first3=Moritaka journal=Zeitschrift f\\u00fcr Kristallographie volume=177 pages=27\\u201338bibcode", "value": NaN}, {"property": "DeltaGf", "value": NaN}, {"property": "DeltaHc", "value": NaN}, {"property": "DeltaHf", "value": NaN}, {"property": "Density", "value": " 2.470 g/cm"}, {"property": "Dipole", "value": NaN}, {"property": "ElectronMobility", "value": NaN}, {"property": "Entropy", "value": NaN}, {"property": "HeatCapacity", "value": NaN}, {"property": "Helical chains making individual single crystals optically active; \\u03b1-quartz converts to \\u03b2-quartz at 846 K[[File:a-quartz.png100px]]-\\u03b2-quartz[[Hexagonal crystal systemhexagonal]]<br/>hP18, P6<sub>2</sub>22, No. 180<ref>{{cite journal doi=10.1016/0022-4596(81)90449-7 title=The structure of quartz at 25 and 590&nbsp;\\u00b0C determined by neutron diffraction year=1981 last1=Wright first1=A. F. last2=Lehmann first2=M. S. journal=Journal of Solid State Chemistry volume=36 issue=3 pages=371\\u201380bibcode", "value": NaN}, {"property": "HenryConstant", "value": NaN}, {"property": "IsoelectricPt", "value": NaN}, {"property": "LambdaMax", "value": NaN}, {"property": "LogP", "value": NaN}, {"property": "MagSus", "value": NaN}, {"property": "MeltingPt", "value": NaN}, {"property": "MeltingPt.1", "value": " "}, {"property": "MeltingPtC", "value": NaN}, {"property": "MeltingPtF", "value": NaN}, {"property": "MeltingPtK", "value": NaN}, {"property": "MeltingPt_notes", "value": NaN}, {"property": "MeltingPt_ref", "value": NaN}, {"property": "MolarMass", "value": " 96.911"}, {"property": "O", "value": NaN}, {"property": "Odor", "value": NaN}, {"property": "Odour", "value": NaN}, {"property": "Properties_ref", "value": NaN}, {"property": "RefractIndex", "value": NaN}, {"property": "RefractIndex.1", "value": NaN}, {"property": "Solubility", "value": " "}, {"property": "Solubility1", "value": NaN}, {"property": "Solubility2", "value": NaN}, {"property": "Solubility2.1", "value": NaN}, {"property": "Solubility3", "value": NaN}, {"property": "SolubilityProduct", "value": NaN}, {"property": "SolubilityProductAs", "value": NaN}, {"property": "SolubleOther", "value": NaN}, {"property": "Solvent", "value": NaN}, {"property": "Solvent1", "value": NaN}, {"property": "Solvent2", "value": NaN}, {"property": "Solvent3", "value": NaN}, {"property": "Solvent4", "value": NaN}, {"property": "Solvent5", "value": NaN}, {"property": "SpecRotation", "value": NaN}, {"property": "SublimationConditions", "value": NaN}, {"property": "ThermalConductivity", "value": NaN}, {"property": "VaporPressure", "value": NaN}, {"property": "Viscosity", "value": NaN}, {"property": "pKa", "value": " 8.65  "}, {"property": "pKb", "value": NaN}, {"property": "tetragonal<br/>tP36, P4<sub>1</sub>2<sub>1</sub>2, No. 92<ref>{{cite journal doi=10.1524/zkri.1959.112.1-6.409 title=The crystal structure of keatite, a new form of silica year=1959 last1=Shropshire first1=Joseph last2=Keat first2=Paul P. last3=Vaughan first3=Philip A. journal=Zeitschrift f\\u00fcr Kristallographie volume=11 ...

# %% [markdown]
# Each compund has multiple properties and the key to see all these properties is the chemical formula. This approach was pretty heavy handed. I can refine more and more, but I believe as a first processing this is a strong method of approach to scrape and reformating.
#
# A few next possible steps:
#
# -- In the future, refine the code to be more readable. Higher comment density.
#
# -- Break up unit/values more effectively from the start, but again, I created a function to recall that information from the dataframe on a column by column basis. It will work with most columns, but some columns have values that are difficult to predict.
#
# -- Master the pypif structures indepth. While I encapsulated each chemical compound within a dictionary, it's not the best way to structure it-- it's effectively a json formatting, but I wasn't able to effectively to feel comfortable with the final results above.
